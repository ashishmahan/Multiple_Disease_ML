# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishmahan/Multiple_Disease_ML/blob/main/detailed%20HLA%20heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
import random
from sklearn.preprocessing import MinMaxScaler


data11 = pd.read_csv('/content/lr.csv', index_col=0)

data1= data11.drop('Total epitopes', axis=1)




X_train, X_test, y_train, y_test = train_test_split(data1, data1['Status'], test_size=0.2, random_state=42)


scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


#class_weights = {0: 1.0, 1: (13/5)}  # Assuming 0 represents healthy and 1 represents active TB


clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train_scaled, y_train)


y_prob = clf.predict_proba(X_test_scaled)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from Bio import SeqIO

fastq_files = ["SRR8185713_1.fastq", "SRR8185713_2.fastq"]
seq_records = []
for fastq_file in fastq_files:
    with open(fastq_file, "r") as in_handle:
        seq_records += list(SeqIO.parse(in_handle, "fastq"))

gene_counts = {}
for seq_record in seq_records:
    gene = seq_record.description.split("|")[1]
    if gene not in gene_counts:
        gene_counts[gene] = 0
    gene_counts[gene] += 1

for gene, count in gene_counts.items():
    print(gene, count)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-cb641561253a> in <cell line: 5>()
#       4 seq_records = []
#       5 for fastq_file in fastq_files:
# ----> 6     with open(fastq_file, "r") as in_handle:
#       7         seq_records += list(SeqIO.parse(in_handle, "fastq"))
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SRR8185713_1.fastq'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install biopython

# %%
pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
scaler=StandardScaler()

# %%
min=MinMaxScaler()

# %%
rob=RobustScaler()

# %%
r=rob.fit_transform(dff)

# %%
r_df=pd.DataFrame(r, columns=dff.columns)

# %%
r_df.index=original_index
original_index=dff.index

# %%
n=min.fit_transform(dff)

# %%
n_df=pd.DataFrame(n, columns=dff.columns)

# %%
n_df.index=original_index
original_index=dff.index

# %%
norm=scaler.fit_transform(dff)

# %%
norm_df=pd.DataFrame(norm, columns=dff.columns)

# %%
norm_df.index=original_index

# %%
original_index=dff.index

# %%
norm_df
# Out:
#                   GNLY     ZAP70   SLC11A1      TNFA     HLA-A     HLA-B  \
# Individuals
# Active TB_0  -1.159511 -0.831166 -0.326223 -0.603117  0.575420  0.767413
# Active TB_6  -1.209025 -1.184769 -0.843366 -0.755102 -1.015279 -1.141267
# Active TB_12 -0.915888 -0.129239  0.789410  0.925181  0.982510  1.398566
# Active TB_0   0.917348  0.864717 -0.326223  0.663428  0.045280  0.333941
# Active TB_6  -0.713305 -1.243702 -0.872419 -0.839538 -1.882684 -1.754748
# Active TB_12 -0.635522 -1.156621 -0.814313 -1.211058 -1.862325 -1.734651
# Active TB_0  -0.455577 -0.821491  3.183373  0.393232  1.394816  1.191324
# Active TB_6   1.423749  0.787312  0.278078 -0.442688 -0.098380 -0.048585
# Active TB_12  1.675382  1.459332  0.469828  0.730977  0.233108  0.106574
# Active TB_0  -0.057375 -0.284050 -0.244875 -0.907087  0.403577  0.610776
# Active TB_12  1.687514  1.340585 -0.454056 -1.084404 -0.111981  0.143493
# Hc1          -0.623913 -0.465250 -0.471488 -0.282259 -0.296864 -1.110320
# ...

# %%
n_df
# Out:
#                   GNLY     ZAP70   SLC11A1      TNFA     HLA-A     HLA-B  \
# Individuals
# Active TB_0   0.017094  0.142337  0.134670  0.171021  0.717841  0.799844
# Active TB_6   0.000000  0.020334  0.007163  0.128266  0.253308  0.194551
# Active TB_12  0.101202  0.384522  0.409742  0.600950  0.836724  1.000000
# Active TB_0   0.734108  0.727466  0.134670  0.527316  0.563024  0.662379
# Active TB_6   0.171142  0.000000  0.000000  0.104513  0.000000  0.000000
# Active TB_12  0.197996  0.030046  0.014327  0.000000  0.005945  0.006373
# Active TB_0   0.260120  0.145675  1.000000  0.451306  0.957130  0.934278
# Active TB_6   0.908938  0.700759  0.283668  0.216152  0.521071  0.541070
# Active TB_12  0.995812  0.932625  0.330946  0.546318  0.617875  0.590275
# Active TB_0   0.397595  0.331108  0.154728  0.085511  0.667658  0.750171
# Active TB_12  1.000000  0.891654  0.103152  0.035629  0.517099  0.601983
# Hc1           0.202004  0.268589  0.098854  0.261283  0.463108  0.204365
# ...

# %%
norm_df
# Out:
#                   GNLY     ZAP70   SLC11A1      TNFA     HLA-A     HLA-B  \
# Individuals
# Active TB_0  -1.159511 -0.831166 -0.326223 -0.603117  0.575420  0.767413
# Active TB_6  -1.209025 -1.184769 -0.843366 -0.755102 -1.015279 -1.141267
# Active TB_12 -0.915888 -0.129239  0.789410  0.925181  0.982510  1.398566
# Active TB_0   0.917348  0.864717 -0.326223  0.663428  0.045280  0.333941
# Active TB_6  -0.713305 -1.243702 -0.872419 -0.839538 -1.882684 -1.754748
# Active TB_12 -0.635522 -1.156621 -0.814313 -1.211058 -1.862325 -1.734651
# Active TB_0  -0.455577 -0.821491  3.183373  0.393232  1.394816  1.191324
# Active TB_6   1.423749  0.787312  0.278078 -0.442688 -0.098380 -0.048585
# Active TB_12  1.675382  1.459332  0.469828  0.730977  0.233108  0.106574
# Active TB_0  -0.057375 -0.284050 -0.244875 -0.907087  0.403577  0.610776
# Active TB_12  1.687514  1.340585 -0.454056 -1.084404 -0.111981  0.143493
# Hc1          -0.623913 -0.465250 -0.471488 -0.282259 -0.296864 -1.110320
# ...

# %%
dff=pd.read_excel('/content/heatmap of gene exp3.xlsx', index_col=0)

# %%
dff
# Out:
#                 GNLY  ZAP70  SLC11A1  TNFA    HLA-A    HLA-B    HLA-C  CTNNB1  \
# Individuals
# Active TB_0    45.73  15.84     13.5  2.32  1115.28  2658.25  2020.53   21.77
# Active TB_6    37.20  11.82      4.6  2.14   548.03  1264.98   947.97   13.20
# Active TB_12   87.70  23.82     32.7  4.13  1260.45  3118.97  2356.37   29.41
# Active TB_0   403.52  35.12     13.5  3.82   926.23  2341.83  1973.11   25.50
# Active TB_6   122.60  11.15      4.1  2.04   238.71   817.16   692.80    7.84
# Active TB_12  136.00  12.14      5.1  1.60   245.97   831.83   695.72   14.80
# Active TB_0   167.00  15.95     73.9  3.50  1407.48  2967.69  1666.52   27.87
# Active TB_6   490.76  34.24     23.9  2.51   875.00  2062.60  1008.88   13.55
# Active TB_12  534.11  41.88     27.2  3.90   993.21  2175.86  1130.74   16.70
# Active TB_0   235.60  22.06     14.9  1.96  1054.00  2543.91  1544.50   19.70
# Active TB_12  536.20  40.53     11.3  1.75   870.15  2202.81  1250.70   20.70
# ...

# %%
plt.figure(figsize=(10,8))
epi_plot= sns.heatmap(norm_df, annot=True, cmap='YlOrRd', fmt='.2f', annot_kws={'size':12}, cbar_kws={'label': 'Gene Expression Strength'})
epi_plot.set_xlabel('Genes from T Cell Response Pathway', fontsize=14)
epi_plot.set_ylabel('Individuals', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,8))
epi_plot= sns.heatmap(n_df, annot=True, cmap='YlOrRd', fmt='.2f', annot_kws={'size':12}, cbar_kws={'label': 'Gene Expression Strength'})
epi_plot.set_xlabel('Genes from T Cell Response Pathway', fontsize=14)
epi_plot.set_ylabel('Individuals', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,8))
epi_plot= sns.heatmap(r_df, annot=True, cmap='YlOrRd', fmt='.2f', annot_kws={'size':12}, cbar_kws={'label': 'Gene Expression Strength'})
epi_plot.set_xlabel('Genes from T Cell Response Pathway', fontsize=14)
epi_plot.set_ylabel('Individuals', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-84457a77475d> in <cell line: 2>()
#       1 plt.figure(figsize=(10,8))
# ----> 2 epi_plot= sns.heatmap(r_df, annot=True, cmap='YlOrRd', fmt='.2f', annot_kws={'size':12}, cbar_kws={'label': 'Gene Expression Strength'})
#       3 epi_plot.set_xlabel('Genes from T Cell Response Pathway', fontsize=14)
#       4 epi_plot.set_ylabel('Individuals', fontsize=14)
#       5 plt.show()
#
# NameError: name 'r_df' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("/content/heatmap of gene exp3(1).xlsx")


# Extract the categories from the first column (x-axis)
categories = df.iloc[:, 0].tolist()

# Extract the values from the first row (y-axis)
values = df.iloc[0, 1:].tolist()

# Create a bar graph
plt.bar(categories, values)

# Add lines connecting the bars
for i in range(1, len(categories)):
    plt.plot([categories[i - 1], categories[i]], [values[i - 1], values[i]], marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('X-Axis Categories')
plt.ylabel('Y-Axis Values')
plt.title('Bar Graph with Lines Connecting Bars')

# Show the graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-eddd3c453b95> in <cell line: 11>()
#       9
#      10 # Create a bar graph
# ---> 11 plt.bar(categories, values)
#      12
#      13 # Add lines connecting the bars
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.read_excel('/content/heatmap of gene exp3.xlsx', header=None)

# Extract the categories (x-axis) from the first row
categories = df.iloc[0, 1:].tolist()

# Extract the values (y-axis) from the first column
values = df.iloc[1:, 0].tolist()

# Create a bar graph
plt.bar(categories, values)

# Add lines connecting the bars
for i in range(1, len(categories)):
    plt.plot([categories[i - 1], categories[i]], [values[i - 1], values[i]], marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('X-Axis Categories')
plt.ylabel('Y-Axis Values')
plt.title('Bar Graph with Lines Connecting Bars')

# Show the graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-cad3ff65fc08> in <cell line: 10>()
#       8
#       9 # Create a bar graph
# ---> 10 plt.bar(categories, values)
#      11
#      12 # Add lines connecting the bars
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
width = .35 # width of a bar

m1_t = pd.DataFrame({
 'abnormal' : [90,40,30,30,30,25,25,20,15,10],
 'fix' : [60,70,65,70,70,60,50,45,45,45],
 'normal' : [140,160,170,180,190,200,210,220,230,240],
 'bad_rate' : [210,100,100,70,70,75,70,60,65,60]})

m1_t[['abnormal','fix','normal']].plot(kind='bar', width = width)
m1_t['bad_rate'].plot(secondary_y=True)

ax = plt.gca()
plt.xlim([-width, len(m1_t['normal'])-width])
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10'))

plt.show()

# %%
df.iloc[0, 1:].plot(kind='bar', width = width)
# Out:
# <Axes: >

# %%
dff
# Out:
#                 GNLY  ZAP70  SLC11A1  TNFA    HLA-A    HLA-B    HLA-C  CTNNB1  \
# Individuals
# Active TB_0    45.73  15.84     13.5  2.32  1115.28  2658.25  2020.53   21.77
# Active TB_6    37.20  11.82      4.6  2.14   548.03  1264.98   947.97   13.20
# Active TB_12   87.70  23.82     32.7  4.13  1260.45  3118.97  2356.37   29.41
# Active TB_0   403.52  35.12     13.5  3.82   926.23  2341.83  1973.11   25.50
# Active TB_6   122.60  11.15      4.1  2.04   238.71   817.16   692.80    7.84
# Active TB_12  136.00  12.14      5.1  1.60   245.97   831.83   695.72   14.80
# Active TB_0   167.00  15.95     73.9  3.50  1407.48  2967.69  1666.52   27.87
# Active TB_6   490.76  34.24     23.9  2.51   875.00  2062.60  1008.88   13.55
# Active TB_12  534.11  41.88     27.2  3.90   993.21  2175.86  1130.74   16.70
# Active TB_0   235.60  22.06     14.9  1.96  1054.00  2543.91  1544.50   19.70
# Active TB_12  536.20  40.53     11.3  1.75   870.15  2202.81  1250.70   20.70
# ...

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(_df_36, *['Individuals'], **{})
chart

# %%
y = df.iloc[:, 1:].tolist()
x= df.iloc[:, 0].tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-1d282591943c> in <cell line: 1>()
# ----> 1 y = df.iloc[:, 1:].tolist()
#       2 x= df.iloc[:, 0].tolist()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
x
# Out:
# 0      Individuals
# 1      Active TB_0
# 2      Active TB_6
# 3     Active TB_12
# 4      Active TB_0
# 5      Active TB_6
# 6     Active TB_12
# 7      Active TB_0
# 8      Active TB_6
# 9     Active TB_12
# 10     Active TB_0
# 11    Active TB_12
# 12             Hc1
# 13             Hc2
# 14             Hc3
# Name: 0, dtype: object

# %%
df
# Out:
#               0       1      2        3     4        5        6        7   \
# 0    Individuals    GNLY  ZAP70  SLC11A1  TNFA    HLA-A    HLA-B    HLA-C
# 1    Active TB_0   45.73  15.84     13.5  2.32  1115.28  2658.25  2020.53
# 2    Active TB_6    37.2  11.82      4.6  2.14   548.03  1264.98   947.97
# 3   Active TB_12    87.7  23.82     32.7  4.13  1260.45  3118.97  2356.37
# 4    Active TB_0  403.52  35.12     13.5  3.82   926.23  2341.83  1973.11
# 5    Active TB_6   122.6  11.15      4.1  2.04   238.71   817.16    692.8
# 6   Active TB_12     136  12.14      5.1   1.6   245.97   831.83   695.72
# 7    Active TB_0     167  15.95     73.9   3.5  1407.48  2967.69  1666.52
# 8    Active TB_6  490.76  34.24     23.9  2.51      875   2062.6  1008.88
# 9   Active TB_12  534.11  41.88     27.2   3.9   993.21  2175.86  1130.74
# 10   Active TB_0   235.6  22.06     14.9  1.96     1054  2543.91   1544.5
# 11  Active TB_12   536.2  40.53     11.3  1.75   870.15  2202.81   1250.7
# ...

# %%
fig, ax = plt.subplots()

# %%
ax.bar(x, y, color='blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-a44ad1434cd2> in <cell line: 1>()
# ----> 1 ax.bar(x, y, color='blue')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2390
#    2391         if orientation == 'vertical':
# -> 2392             self._process_unit_info(
#    2393                 [("x", x), ("y", height)], kwargs, convert=False)
#    2394             if log:
#
# ...

# %%
dfw=pd.read_excel('/content/Book1.xlsx')

# %%
dfw
# Out:
#     HLA Alleles  Healthy Control     n=3  Active TB    n=4
# 0   HLA-A*24:02                        0                 4
# 1   HLA-A*02:01                        0                 1
# 2   HLA-A*11:01                        1                 1
# 3   HLA-A*33:03                        0                 1
# 4   HLA-A*24:07                        1                 0
# 5   HLA-A*02:11                        1                 0
# 6   HLA-A*03:01                        1                 0
# 7   HLA-A*29:01                        1                 0
# 8   HLA-A*68:01                        1                 0
# 9   HLA-A*26:01                        0                 1
# 10  HLA-B*07:02                        0                 1
# 11  HLA-B*35:01                        0                 1
# 12  HLA-B*15:12                        0                 1
# 13  HLA-B*44:03                        0                 1
# 14  HLA-B*40:02                        0                 1
# ...

# %%
fsc=pd.read_excel('/content/heatmap of gene exp3(3).xlsx', index_col=0)

# %%
fsc
# Out:
#                   GNLY     ZAP70   SLC11A1      TNFA     HLA-A     HLA-B  \
# Individuals
# Active TB_0   1.660201  1.199755  1.130334  0.365488  3.047384  3.424596
# Active TB_6   1.570543  1.072617  0.662758  0.330414  2.738804  3.102084
# Active TB_12  1.943000  1.376942  1.514548  0.615950  3.100526  3.494011
# Active TB_0   2.605865  1.545555  1.130334  0.582063  2.966719  3.369555
# Active TB_6   2.088490  1.047275  0.612784  0.309630  2.377871  2.912307
# Active TB_12  2.133539  1.084219  0.707570  0.204120  2.390882  2.920035
# Active TB_0   2.222716  1.202761  1.868644  0.544068  3.148442  3.472419
# Active TB_6   2.690869  1.534534  1.378398  0.399674  2.942008  3.314415
# Active TB_12  2.727631  1.622007  1.434569  0.591065  2.997041  3.337631
# Active TB_0   2.372175  1.343606  1.173186  0.292256  3.022841  3.405502
# Active TB_12  2.729327  1.607777  1.053078  0.243038  2.939594  3.342977
# Hc1           2.139879  1.301030  1.041393  0.431364  2.905375  3.109771
# ...

# %%
plt.figure(figsize=(10,8))
epi_plot= sns.heatmap(fsc, annot=False, cmap='plasma', fmt='.2f', annot_kws={'size':12}, cbar_kws={'label': 'Gene Expression Strength'})
epi_plot.set_xlabel('Genes from T Cell Response Pathway', fontsize=14)
epi_plot.set_ylabel('Individuals', fontsize=14)
plt.show()

# %%
k=int(input('Enter a number '))
arr=[1,2,3,-3,1,1,1,4,2,-3]
count=0
for i in range(0,len(arr)):
  sum=0
  for j in range(i, len(arr)):
    sum+=arr[j]
  if sum==k:
      count+=1
print(count)
# Out:
# Enter a number 1
# 0
