# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishmahan/Multiple_Disease_ML/blob/main/HLA%20Heatmap%20and%20general.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df= pd.read_excel('/content/pheat.xlsx', index_col=0)

# %%
import pandas as pd

# %%
df
# Out:
#              Ag85B  EsxA  Mpt64  Pks12  Hsp65  EsxB
# allele
# HLA-B*35:01      4     0      2     37      0     0
# HLA-A*02:01      3     2      4     55      3     0
# HLA-B*07:02      2     0      2     21      1     0
# HLA-C*03:03      6     2      2    112      5     0
# HLA-C*03:02      9     0      5     66      1     0
# HLA-B*58:01      3     0      1     20      0     0
# HLA-B*40:02      3     0      1     19      1     0
# HLA-C*15:02      3     0      0     15      0     0
# HLA-A*68:01      2     2      1     50      2     1
# HLA-B*07:05      3     0      4     34      2     0
# HLA-A*29:01      3     0      1      6      0     0
# HLA-B*50:01      2     0      0      8      2     0
# HLA-A*02:11     11     4      6    130     17     1
# HLA-B*40:06      2     0      0      4      0     0
# HLA-A*24:07      1     0      0      0      0     0
# HLA-A*11:01      0     0      2     27      6     0
# HLA-A*33:03      0     0      1     23      0     0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10,8))
epi_plot= sns.heatmap(df, annot=True, cmap='YlOrRd', fmt='', annot_kws={'size':12}, cbar_kws={'label': 'Epitope Detection Strength'})
epi_plot.set_xlabel('Mtb H37Rv Proteins', fontsize=14)
epi_plot.set_ylabel('HLA Alleles from TB patients and Healthy controls', fontsize=14)
plt.show()

# %%
a=256
b=256
print(a is b)
# Out:
# True

# %%
c=257
d=257
print(c is d)
# Out:
# False
